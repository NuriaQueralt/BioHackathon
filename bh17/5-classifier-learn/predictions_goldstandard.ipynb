# %% [markdown]
# # Predictions evaluation
#
# On reproduction/2-predictions:
#
#     * Model (Log. Reg.): P: 0.966, R: 0.966, F: 0.964  10-fold cross-validation
#     * Train set: shape = 1:10 size = 8306 dim = (8306, 201)
#     * Predictions: size = 210706

# %%
import pandas as pd

# %% [markdown]
# ### Gold standard
#
#     * source: https://raw.githubusercontent.com/dhimmel/indications/11d535ba0884ee56c3cd5756fdfb4985f313bd80/catalog/indications.tsv

# %%
# read indications catalog used in the graph
df = pd.read_table('./gold-standard/indications.tsv')
gold_df = df[['doid_id','drugbank_id','disease', 'drug', 'category']].copy()
print(gold_df.size, gold_df.shape)
gold_df.head()
# Out:
# 6940 (1388, 5)
#       doid_id drugbank_id              disease          drug category
# 0  DOID:10652     DB00843  Alzheimer's disease     Donepezil       DM
# 1  DOID:10652     DB00674  Alzheimer's disease   Galantamine       DM
# 2  DOID:10652     DB01043  Alzheimer's disease     Memantine       DM
# 3  DOID:10652     DB00989  Alzheimer's disease  Rivastigmine       DM
# 4  DOID:10652     DB00245  Alzheimer's disease  Benzatropine      SYM

# %%
gold_df.groupby('category').count()
# Out:
#           doid_id  drugbank_id  disease  drug
# category
# DM            755          755      755   755
# NOT           243          243      243   243
# SYM           390          390      390   390

# %%
# set true indications dataframe
indications_df = gold_df.query('category == "DM"').reset_index().copy()
print(indications_df.shape)
print('diseases: {}, drugs: {}'.format(indications_df.disease.nunique(), indications_df.drug.nunique()))
indications_df.head()
# Out:
# (755, 6)
# diseases: 77, drugs: 387
#    index     doid_id drugbank_id              disease          drug category
# 0      0  DOID:10652     DB00843  Alzheimer's disease     Donepezil       DM
# 1      1  DOID:10652     DB00674  Alzheimer's disease   Galantamine       DM
# 2      2  DOID:10652     DB01043  Alzheimer's disease     Memantine       DM
# 3      3  DOID:10652     DB00989  Alzheimer's disease  Rivastigmine       DM
# 4     16   DOID:9206     DB00736  Barrett's esophagus  Esomeprazole       DM

# %%
# unique diseases
print(indications_df.disease.unique())
# Out:
# ["Alzheimer's disease" "Barrett's esophagus" "Crohn's disease"
#  "Graves' disease" 'Kawasaki disease' "Paget's disease of bone"
#  'acquired immunodeficiency syndrome' 'alcohol dependence'
#  'allergic rhinitis' 'alopecia areata' 'amyotrophic lateral sclerosis'
#  'ankylosing spondylitis' 'asthma' 'atherosclerosis' 'atopic dermatitis'
#  'azoospermia' 'bone cancer' 'brain cancer' 'breast cancer'
#  'cervical cancer' 'chronic obstructive pulmonary disease' 'colon cancer'
#  'coronary artery disease' 'dilated cardiomyopathy' 'epilepsy syndrome'
#  'esophageal cancer' 'focal segmental glomerulosclerosis'
#  'germ cell cancer' 'gestational diabetes' 'glaucoma' 'gout'
#  'head and neck cancer' 'hematologic cancer' 'hepatitis B' 'hypertension'
#  'hypothyroidism' 'kidney cancer' 'leprosy' 'liver cancer' 'lung cancer'
#  'lymphatic system cancer' 'malaria' 'malignant glioma' 'melanoma'
#  'metabolic syndrome X' 'migraine' 'multiple sclerosis' 'muscle cancer'
#  'nephrolithiasis' 'nicotine dependence' 'obesity' 'ocular cancer'
#  'osteoporosis' 'ovarian cancer' 'pancreatic cancer' 'pancreatitis'
#  'peripheral nervous system neoplasm' 'polycystic ovary syndrome'
#  'primary biliary cirrhosis' 'prostate cancer' 'psoriasis'
#  'psoriatic arthritis' 'rheumatoid arthritis' 'sarcoma' 'skin cancer'
#  'stomach cancer' 'systemic lupus erythematosus' 'systemic scleroderma'
#  'testicular cancer' 'thymus cancer' 'thyroid cancer'
#  'type 1 diabetes mellitus' 'type 2 diabetes mellitus' 'ulcerative colitis'
#  'urinary bladder cancer' 'uterine cancer' 'vitiligo']

# %%
# unique drugs
print(indications_df.drug.unique())
# Out:
# ['Donepezil' 'Galantamine' 'Memantine' 'Rivastigmine' 'Esomeprazole'
#  'Omeprazole' 'Azathioprine' 'Balsalazide' 'Mercaptopurine' 'Mesalazine'
#  'Prednisone' 'Sulfasalazine' 'Methimazole' 'Propylthiouracil'
#  'Acetylsalicylic acid' 'Alendronate' 'Etidronic acid' 'Pamidronate'
#  'Risedronate' 'Tiludronate' 'Zoledronate' 'Abacavir' 'Amprenavir'
#  'Delavirdine' 'Didanosine' 'Efavirenz' 'Indinavir' 'Lamivudine'
#  'Lopinavir' 'Nelfinavir' 'Nevirapine' 'Ritonavir' 'Saquinavir' 'Stavudine'
#  'Zidovudine' 'Acamprosate' 'Citalopram' 'Disulfiram' 'Naltrexone'
#  'Betamethasone' 'Cetirizine' 'Cyproheptadine' 'Desloratadine'
#  'Dexamethasone' 'Dimenhydrinate' 'Diphenhydramine' 'Flunisolide'
#  'Hydrocortisone' 'Loratadine' 'Methylprednisolone' 'Montelukast'
#  'Olopatadine' 'Prednisolone' 'Triamcinolone' 'Riluzole' 'Methotrexate'
#  'Aminophylline' 'Arformoterol' 'Beclomethasone' 'Budesonide' 'Ciclesonide'
#  'Cromoglicic acid' 'Dyphylline' 'Fluticasone Propionate'
#  'Fluticasone furoate' 'Formoterol' 'Indacaterol' 'Ipratropium bromide'
#  'Isoetarine' 'Isoprenaline' 'Ketotifen' 'Mometasone' 'Nedocromil'
#  'Orciprenaline' 'Pirbuterol' 'Salbutamol' 'Salmeterol' 'Terbutaline'
#  'Theophylline' 'Tiotropium' 'WF10' 'Zafirlukast' 'Zileuton' 'Ezetimibe'
#  'Lovastatin' 'Niacin' 'Pravastatin' 'Rosuvastatin' 'Simvastatin'
#  'Desonide' 'Fluocinolone Acetonide' 'Fluocinonide' 'Pimecrolimus'
#  'Tacrolimus' 'Clomifene' 'Carboplatin' 'Cisplatin' 'Doxorubicin'
#  'Epirubicin' 'Carmustine' 'Etoposide' 'Hydroxyurea' 'Lomustine'
#  'Procarbazine' 'Temozolomide' 'Anastrozole' 'Capecitabine' 'Chlorambucil'
#  'Docetaxel' 'Eribulin' 'Exemestane' 'Fluorouracil' 'Fluoxymesterone'
#  'Fulvestrant' 'Gemcitabine' 'Goserelin' 'Idarubicin' 'Irinotecan'
#  'Ixabepilone' 'Lapatinib' 'Letrozole' 'Melphalan' 'Mitoxantrone'
#  'Paclitaxel' 'Raloxifene' 'Tamoxifen' 'Thiotepa' 'Toremifene'
#  'Vinblastine' 'Vinorelbine' 'Topotecan' 'Roflumilast' 'Vincristine'
#  'Atorvastatin' 'Captopril' 'Clopidogrel' 'Enalapril' 'Eplerenone'
#  'Fenofibrate' 'Furosemide' 'Gemfibrozil' 'Lisinopril' 'Losartan'
#  'Olmesartan' 'Penbutolol' 'Perindopril' 'Pitavastatin' 'Ramipril'
#  'Telmisartan' 'Ticagrelor' 'Timolol' 'Tirofiban' 'Trandolapril'
#  'Valsartan' 'Spironolactone' 'Acetazolamide' 'Amobarbital' 'Carbamazepine'
#  'Clobazam' 'Clonazepam' 'Diazepam' 'Felbamate' 'Fosphenytoin' 'Gabapentin'
#  'Lacosamide' 'Lamotrigine' 'Levetiracetam' 'Midazolam' 'Oxcarbazepine'
#  'Phenobarbital' 'Phenytoin' 'Pregabalin' 'Primidone' 'Propofol'
#  'Rufinamide' 'Topiramate' 'Trimethadione' 'Valproic Acid' 'Vigabatrin'
#  'Zonisamide' 'Cyclosporine' 'Bleomycin' 'Dactinomycin' 'Ifosfamide'
#  'Glyburide' 'Apraclonidine' 'Betaxolol' 'Bimatoprost' 'Brimonidine'
#  'Brinzolamide' 'Carbachol' 'Carteolol' 'Clonidine' 'Diclofenamide'
#  'Dipivefrin' 'Dorzolamide' 'Echothiophate' 'Latanoprost' 'Levobunolol'
#  'Methazolamide' 'Metipranolol' 'Physostigmine' 'Pilocarpine' 'Travoprost'
#  'Allopurinol' 'Colchicine' 'Indomethacin' 'Naproxen' 'Probenecid'
#  'Alitretinoin' 'Anagrelide' 'Bexarotene' 'Bortezomib' 'Busulfan'
#  'Cladribine' 'Clofarabine' 'Cytarabine' 'Dacarbazine' 'Dasatinib'
#  'Daunorubicin' 'Fludarabine' 'Imatinib' 'Lenalidomide' 'Mechlorethamine'
#  'Methoxsalen' 'Nelarabine' 'Nilotinib' 'Pentostatin' 'Ruxolitinib'
#  'Teniposide' 'Thalidomide' 'Tioguanine' 'Vorinostat' 'Adefovir Dipivoxil'
#  'Entecavir' 'Telbivudine' 'Acebutolol' 'Amiloride' 'Amlodipine'
#  'Benazepril' 'Bendroflumethiazide' 'Bepridil' 'Bumetanide' 'Candesartan'
#  'Carvedilol' 'Chlorothiazide' 'Chlorthalidone' 'Diltiazem' 'Doxazosin'
#  'Eprosartan' 'Esmolol' 'Ethacrynic acid' 'Felodipine' 'Fenoldopam'
#  'Fosinopril' 'Guanabenz' 'Guanadrel' 'Guanethidine' 'Guanfacine'
#  'Hydralazine' 'Hydrochlorothiazide' 'Hydroflumethiazide' 'Indapamide'
#  'Irbesartan' 'Isradipine' 'Labetalol' 'Mecamylamine' 'Methyldopa'
#  'Metolazone' 'Metoprolol' 'Minoxidil' 'Moexipril' 'Nadolol' 'Nebivolol'
#  'Nicardipine' 'Nifedipine' 'Nisoldipine' 'Pindolol' 'Prazosin'
#  'Propranolol' 'Quinapril' 'Reserpine' 'Terazosin' 'Torasemide'
#  'Triamterene' 'Verapamil' 'Dextrothyroxine' 'Levothyroxine' 'Liothyronine'
#  'Liotrix' 'Erlotinib' 'Everolimus' 'Pazopanib' 'Sorafenib' 'Sunitinib'
#  'Temsirolimus' 'Dapsone' 'Rifampicin' 'Crizotinib' 'Gefitinib'
#  'Pemetrexed' 'Artemether' 'Clindamycin' 'Doxycycline' 'Pentoxifylline'
#  'Proguanil' 'Pyrimethamine' 'Quinidine' 'Quinidine barbiturate' 'Quinine'
#  'Sulfadiazine' 'Vemurafenib' 'Metformin' 'Amitriptyline' 'Fingolimod'
#  'Varenicline' 'Benzphetamine' 'Bupropion' 'Cimetidine' 'Diethylpropion'
#  'Methamphetamine' 'Orlistat' 'Phendimetrazine' 'Phentermine'
#  'Phenylpropanolamine' 'Sibutramine' 'Calcitriol' 'Calcium Acetate'
#  'Cholecalciferol' 'Conjugated Estrogens' 'Ergocalciferol' 'Estradiol'
#  'Estropipate' 'Ethinyl Estradiol' 'Ibandronate' 'Altretamine'
#  'Hyoscyamine' 'Propantheline' 'Isotretinoin' 'Tretinoin'
#  'Chenodeoxycholic acid' 'Ursodeoxycholic acid' 'Abiraterone'
#  'Bicalutamide' 'Cabazitaxel' 'Degarelix' 'Estradiol valerate/Dienogest'
#  'Estramustine' 'Estrone' 'Flutamide' 'Nilutamide' 'Vitamin C' 'Acitretin'
#  'Calcipotriol' 'Clobetasol propionate' 'Mycophenolate mofetil'
#  'Mycophenolic acid' 'Tazarotene' 'Auranofin' 'Leflunomide' 'Penicillamine'
#  'Imiquimod' 'Vismodegib' 'Floxuridine' 'Mitomycin' 'Octreotide'
#  'Vandetanib' 'Acarbose' 'Bromocriptine' 'Chlorpropamide' 'Gliclazide'
#  'Glimepiride' 'Glipizide' 'Linagliptin' 'Miglitol' 'Nateglinide'
#  'Pioglitazone' 'Repaglinide' 'Rosiglitazone' 'Sitagliptin' 'Tolazamide'
#  'Tolbutamide' 'Nicotine' 'Olsalazine' 'Valrubicin'
#  'Medroxyprogesterone Acetate' 'Progesterone']

# %% [markdown]
# ### Select instances
#
# The selection of Indications should be divers, i.e. diseases belonging to different disease classes, and with different amount of drug information available for the training step.

# %%
# gruop by disease: they range [68 - 1]
indications_df.groupby('disease')['drug'].count().sort_values(ascending=False)
# Out:
# disease
# hypertension                          68
# hematologic cancer                    51
# asthma                                37
# breast cancer                         29
# coronary artery disease               28
# epilepsy syndrome                     25
# type 2 diabetes mellitus              22
# psoriasis                             21
# glaucoma                              21
# prostate cancer                       21
# ulcerative colitis                    16
# lung cancer                           16
# atopic dermatitis                     16
# allergic rhinitis                     15
# osteoporosis                          15
# rheumatoid arthritis                  15
# acquired immunodeficiency syndrome    14
# kidney cancer                         13
# systemic lupus erythematosus          13
# peripheral nervous system neoplasm    12
# multiple sclerosis                    11
# obesity                               11
# urinary bladder cancer                11
# testicular cancer                     11
# malaria                               11
# systemic scleroderma                  10
# pancreatic cancer                     10
# ovarian cancer                        10
# lymphatic system cancer                9
# gout                                   9
#                                       ..
# head and neck cancer                   4
# hepatitis B                            4
# hypothyroidism                         4
# alcohol dependence                     4
# esophageal cancer                      4
# thyroid cancer                         4
# Alzheimer's disease                    4
# liver cancer                           3
# dilated cardiomyopathy                 3
# leprosy                                3
# primary biliary cirrhosis              3
# pancreatitis                           2
# Barrett's esophagus                    2
# malignant glioma                       2
# Graves' disease                        2
# ocular cancer                          2
# type 1 diabetes mellitus               1
# Kawasaki disease                       1
# thymus cancer                          1
# polycystic ovary syndrome              1
# amyotrophic lateral sclerosis          1
# alopecia areata                        1
# focal segmental glomerulosclerosis     1
# nicotine dependence                    1
# nephrolithiasis                        1
# metabolic syndrome X                   1
# azoospermia                            1
# gestational diabetes                   1
# cervical cancer                        1
# vitiligo                               1
# Name: drug, Length: 77, dtype: int64

# %%
# 1. hypertension DOID:10763 (68 drugs)
indications_df.query('doid_id == "DOID:10763"')
# Out:
#      index     doid_id drugbank_id       disease                 drug category
# 338    628  DOID:10763     DB01193  hypertension           Acebutolol       DM
# 339    629  DOID:10763     DB00594  hypertension            Amiloride       DM
# 340    630  DOID:10763     DB00381  hypertension           Amlodipine       DM
# 341    631  DOID:10763     DB01076  hypertension         Atorvastatin       DM
# 342    632  DOID:10763     DB00542  hypertension           Benazepril       DM
# 343    633  DOID:10763     DB00436  hypertension  Bendroflumethiazide       DM
# 344    634  DOID:10763     DB01244  hypertension             Bepridil       DM
# 345    635  DOID:10763     DB00195  hypertension            Betaxolol       DM
# 346    636  DOID:10763     DB00887  hypertension           Bumetanide       DM
# 347    637  DOID:10763     DB00796  hypertension          Candesartan       DM
# 348    638  DOID:10763     DB01197  hypertension            Captopril       DM
# 349    639  DOID:10763     DB01136  hypertension           Carvedilol       DM
# 350    640  DOID:10763     DB00880  hypertension       Chlorothiazide       DM
# 351    641  DOID:10763     DB00310  hypertension       Chlorthalidone       DM
# 352    642  DOID:10763     DB00575  hypertension            Clonidine       DM
# 353    643  DOID:10763     DB00343  hypertension            Diltiazem       DM
# 354    644  DOID:10763     DB00590  hypertension            Doxazosin       DM
# 355    645  DOID:10763     DB00584  hypertension            Enalapril       DM
# 356    646  DOID:10763     DB00700  hypertension           Eplerenone       DM
# 357    647  DOID:10763     DB00876  hypertension           Eprosartan       DM
# 358    648  DOID:10763     DB00187  hypertension              Esmolol       DM
# 359    649  DOID:10763     DB00903  hypertension      Ethacrynic acid       DM
# 360    650  DOID:10763     DB01023  hypertension           Felodipine       DM
# 361    651  DOID:10763     DB00800  hypertension           Fenoldopam       DM
# 362    652  DOID:10763     DB00492  hypertension           Fosinopril       DM
# 363    653  DOID:10763     DB00695  hypertension           Furosemide       DM
# 364    654  DOID:10763     DB00629  hypertension            Guanabenz       DM
# 365    655  DOID:10763     DB00226  hypertension            Guanadrel       DM
# 366    656  DOID:10763     DB01170  hypertension         Guanethidine       DM
# 367    657  DOID:10763     DB01018  hypertension           Guanfacine       DM
# ..     ...         ...         ...           ...                  ...      ...
# 376    666  DOID:10763     DB00678  hypertension             Losartan       DM
# 377    667  DOID:10763     DB00657  hypertension         Mecamylamine       DM
# 378    668  DOID:10763     DB00968  hypertension           Methyldopa       DM
# 379    669  DOID:10763     DB00524  hypertension           Metolazone       DM
# 380    670  DOID:10763     DB00264  hypertension           Metoprolol       DM
# 381    671  DOID:10763     DB00350  hypertension            Minoxidil       DM
# 382    672  DOID:10763     DB00691  hypertension            Moexipril       DM
# 383    673  DOID:10763     DB01203  hypertension              Nadolol       DM
# 384    674  DOID:10763     DB04861  hypertension            Nebivolol       DM
# 385    675  DOID:10763     DB00622  hypertension          Nicardipine       DM
# 386    676  DOID:10763     DB01115  hypertension           Nifedipine       DM
# 387    677  DOID:10763     DB00401  hypertension          Nisoldipine       DM
# 388    678  DOID:10763     DB00275  hypertension           Olmesartan       DM
# 389    679  DOID:10763     DB01359  hypertension           Penbutolol       DM
# 390    680  DOID:10763     DB00790  hypertension          Perindopril       DM
# 391    681  DOID:10763     DB00960  hypertension             Pindolol       DM
# 392    682  DOID:10763     DB00457  hypertension             Prazosin       DM
# 393    683  DOID:10763     DB00571  hypertension          Propranolol       DM
# 394    684  DOID:10763     DB00881  hypertension            Quinapril       DM
# 395    685  DOID:10763     DB00178  hypertension             Ramipril       DM
# 396    686  DOID:10763     DB00206  hypertension            Reserpine       DM
# 397    687  DOID:10763     DB00421  hypertension       Spironolactone       DM
# 398    688  DOID:10763     DB00966  hypertension          Telmisartan       DM
# 399    689  DOID:10763     DB01162  hypertension            Terazosin       DM
# 400    690  DOID:10763     DB00373  hypertension              Timolol       DM
# 401    691  DOID:10763     DB00214  hypertension           Torasemide       DM
# 402    692  DOID:10763     DB00519  hypertension         Trandolapril       DM
# 403    693  DOID:10763     DB00384  hypertension          Triamterene       DM
# 404    694  DOID:10763     DB00177  hypertension            Valsartan       DM
# 405    695  DOID:10763     DB00661  hypertension            Verapamil       DM
#
# [68 rows x 6 columns]

# %%
# 2. epilepsy DOID:1826 (25 drugs)
indications_df.query('doid_id == "DOID:1826"')
# Out:
#      index    doid_id drugbank_id            disease           drug category
# 211    472  DOID:1826     DB00819  epilepsy syndrome  Acetazolamide       DM
# 212    473  DOID:1826     DB01351  epilepsy syndrome    Amobarbital       DM
# 213    474  DOID:1826     DB00564  epilepsy syndrome  Carbamazepine       DM
# 214    475  DOID:1826     DB00349  epilepsy syndrome       Clobazam       DM
# 215    476  DOID:1826     DB01068  epilepsy syndrome     Clonazepam       DM
# 216    477  DOID:1826     DB00829  epilepsy syndrome       Diazepam       DM
# 217    478  DOID:1826     DB00949  epilepsy syndrome      Felbamate       DM
# 218    479  DOID:1826     DB01320  epilepsy syndrome   Fosphenytoin       DM
# 219    480  DOID:1826     DB00996  epilepsy syndrome     Gabapentin       DM
# 220    481  DOID:1826     DB06218  epilepsy syndrome     Lacosamide       DM
# 221    482  DOID:1826     DB00555  epilepsy syndrome    Lamotrigine       DM
# 222    483  DOID:1826     DB01202  epilepsy syndrome  Levetiracetam       DM
# 223    484  DOID:1826     DB00683  epilepsy syndrome      Midazolam       DM
# 224    485  DOID:1826     DB00776  epilepsy syndrome  Oxcarbazepine       DM
# 225    486  DOID:1826     DB01174  epilepsy syndrome  Phenobarbital       DM
# 226    487  DOID:1826     DB00252  epilepsy syndrome      Phenytoin       DM
# 227    488  DOID:1826     DB00230  epilepsy syndrome     Pregabalin       DM
# 228    489  DOID:1826     DB00794  epilepsy syndrome      Primidone       DM
# 229    490  DOID:1826     DB00818  epilepsy syndrome       Propofol       DM
# 230    491  DOID:1826     DB06201  epilepsy syndrome     Rufinamide       DM
# 231    492  DOID:1826     DB00273  epilepsy syndrome     Topiramate       DM
# 232    493  DOID:1826     DB00347  epilepsy syndrome  Trimethadione       DM
# 233    494  DOID:1826     DB00313  epilepsy syndrome  Valproic Acid       DM
# 234    495  DOID:1826     DB01080  epilepsy syndrome     Vigabatrin       DM
# 235    496  DOID:1826     DB00909  epilepsy syndrome     Zonisamide       DM

# %%
# 3. malaria DOID:12365 (11 drugs)
indications_df.query('doid_id == "DOID:12365"')
# Out:
#      index     doid_id drugbank_id  disease                   drug category
# 454    808  DOID:12365     DB06697  malaria             Artemether       DM
# 455    809  DOID:12365     DB01190  malaria            Clindamycin       DM
# 456    810  DOID:12365     DB00250  malaria                Dapsone       DM
# 457    811  DOID:12365     DB00254  malaria            Doxycycline       DM
# 458    812  DOID:12365     DB00806  malaria         Pentoxifylline       DM
# 459    813  DOID:12365     DB01131  malaria              Proguanil       DM
# 460    814  DOID:12365     DB00205  malaria          Pyrimethamine       DM
# 461    815  DOID:12365     DB00908  malaria              Quinidine       DM
# 462    816  DOID:12365     DB01346  malaria  Quinidine barbiturate       DM
# 463    817  DOID:12365     DB00468  malaria                Quinine       DM
# 464    818  DOID:12365     DB00359  malaria           Sulfadiazine       DM

# %%
# 4. thyroid cancer DOID:1781 (4 drugs)
indications_df.query('doid_id == "DOID:1781"')
# Out:
#      index    doid_id drugbank_id         disease         drug category
# 693   1311  DOID:1781     DB00997  thyroid cancer  Doxorubicin       DM
# 694   1312  DOID:1781     DB00445  thyroid cancer   Epirubicin       DM
# 695   1313  DOID:1781     DB00398  thyroid cancer    Sorafenib       DM
# 696   1314  DOID:1781     DB05294  thyroid cancer   Vandetanib       DM

# %%
# 5. obesity DOID:9970 (11 drugs)
indications_df.query('doid_id == "DOID:9970"')
# Out:
#      index    doid_id drugbank_id  disease                 drug category
# 501    918  DOID:9970     DB00865  obesity        Benzphetamine       DM
# 502    919  DOID:9970     DB01156  obesity            Bupropion       DM
# 503    920  DOID:9970     DB00501  obesity           Cimetidine       DM
# 504    921  DOID:9970     DB00937  obesity       Diethylpropion       DM
# 505    922  DOID:9970     DB01577  obesity      Methamphetamine       DM
# 506    923  DOID:9970     DB01083  obesity             Orlistat       DM
# 507    924  DOID:9970     DB01579  obesity      Phendimetrazine       DM
# 508    925  DOID:9970     DB00191  obesity          Phentermine       DM
# 509    926  DOID:9970     DB00397  obesity  Phenylpropanolamine       DM
# 510    927  DOID:9970     DB01105  obesity          Sibutramine       DM
# 511    928  DOID:9970     DB00273  obesity           Topiramate       DM

# %% [markdown]
# ### Predictions

# %%
# read predictions
predictions_df = pd.read_csv('./reproduction/2-predictions/predictions_mapped.csv', sep=',', header=None)
predictions_df = predictions_df.rename(
    columns={ 
        0: 'drug', 
        1: 'disease', 
        2: 'actual', 
        3: 'predicted', 
        4: 'error', 
        5: 'prediction'
    }
)
predictions_df = predictions_df[['drug', 'disease', 'predicted', 'prediction']]
predictions_df['predicted'] = predictions_df.predicted.apply(lambda x: 'true' if x.split(':')[1] == 't' else 'false')

# Include entity names alongside IDs
# Mapping disease names
url = 'https://raw.githubusercontent.com/dhimmel/disease-ontology/75050ea2d4f60e745d3f3578ae03560a2cc0e444/data/slim-terms.tsv'
disease_df = pd.read_table(url)
disease_df = disease_df[['doid','name','pathophysiology']] 
disease_df['doid'] = ( disease_df
                  .doid
                  .apply(
                      lambda y: y.replace(':','_')
                        )
                          
             )
disease_df = disease_df.rename(columns={'doid': 'disease', 'name': 'disease_name', 'pathophysiology': 'disease_pathophysiology'})

# Mapping drug names
url = 'https://raw.githubusercontent.com/dhimmel/drugbank/3e87872db5fca5ac427ce27464ab945c0ceb4ec6/data/drugbank-slim.tsv'
compound_df = pd.read_table(url)
compound_df = compound_df[['drugbank_id','name','categories']]
compound_df = compound_df.rename(columns={'drugbank_id': 'drug', 'name': 'drug_name', 'categories': 'drug_categories'})

# mapping names to predictions dataframe
predictions_df = pd.merge(predictions_df,compound_df, how='left', on='drug')
predictions_df = pd.merge(predictions_df,disease_df,how='left',on='disease')

# explore true
print('TRUE INDICATIONS')
print(indications_df.shape)
print('diseases: {}, drugs: {}'.format(indications_df.disease.nunique(), indications_df.drug.nunique()))
print()

# explore predictions
print('PREDICTIONS')
print(predictions_df.shape)
print('diseases: {}, drugs: {}'.format(predictions_df.disease.nunique(), predictions_df.drug.nunique()))
predictions_df.head()
# Out:
# TRUE INDICATIONS
# (755, 6)
# diseases: 77, drugs: 387
#
# PREDICTIONS
# (210706, 8)
# diseases: 137, drugs: 1538
#       drug     disease predicted  prediction  drug_name drug_categories  \
# 0  DB00843  DOID_10652     false       0.958  Donepezil             NaN
# 1  DB00843   DOID_9206     false       0.980  Donepezil             NaN
# 2  DB00843   DOID_8778     false       0.932  Donepezil             NaN
# 3  DB00843  DOID_12361     false       0.980  Donepezil             NaN
# 4  DB00843  DOID_13378     false       0.991  Donepezil             NaN
#
#           disease_name disease_pathophysiology
# 0  Alzheimer's disease            degenerative
# 1  Barrett's esophagus              neoplastic
# 2      Crohn's disease             immunologic
# 3      Graves' disease             immunologic
# 4     Kawasaki disease             immunologic

# %%
# 1. hypertension DOID:10763 (68 drugs)
print('Indications: %s' % len(indications_df.query('doid_id == "DOID:10763"')))

# predictions
print('True predictions: {} ({}%)'.format(len(predictions_df.query('disease == "DOID_10763" & predicted == "true"')),round(len(predictions_df.query('disease == "DOID_10763" & predicted == "true"'))*100/len(predictions_df.query('disease == "DOID_10763"')))))

# overlap
indi = set(indications_df.query('doid_id == "DOID:10763"')[['drug']].drug)
pred = set(predictions_df.query('disease == "DOID_10763" & predicted == "true"')[['drug_name']].drug_name)
overlap = pred & indi
print('Indications predicted: {}\n'.format(len(overlap)))
#print(overlap)
#print('\nIndications not predicted: {}'.format(indi - pred))
print()
true = predictions_df.query('disease == "DOID_10763" & predicted == "true"')
print('Percentage of true predictions (P = 1): {}%'.format(round(
            100*len(true.query('prediction == 1'))/len(true)))
     )
print('Number of true predictions (P = 1): {}'.format(
            len(true.query('prediction == 1')))
     )

# overlap
indi = set(indications_df.query('doid_id == "DOID:10763"')[['drug']].drug)
pred = set(predictions_df.query('disease == "DOID_10763" & predicted == "true" & prediction == 1.')[['drug_name']].drug_name)
overlap = pred & indi
print('Indications predicted: {}\n'.format(len(overlap)))
#print(overlap)
#print('\nIndications not predicted: {}'.format(indi - pred))
print()
predictions_df.query('disease == "DOID_10763" & predicted == "true" & prediction == 1.').sort_values(by= 'prediction', ascending= False)
# Out:
# Indications: 68
# True predictions: 1154 (75%)
# Indications predicted: 58
#
#
# Percentage of true predictions (P = 1): 63%
# Number of true predictions (P = 1): 731
# Indications predicted: 31
#            drug     disease predicted  prediction               drug_name  \
# 7843    DB01274  DOID_10763      true         1.0            Arformoterol
# 143610  DB01141  DOID_10763      true         1.0              Micafungin
# 144021  DB01147  DOID_10763      true         1.0             Cloxacillin
# 144158  DB01148  DOID_10763      true         1.0               Flavoxate
# 144295  DB01153  DOID_10763      true         1.0           Sertaconazole
# 144432  DB01154  DOID_10763      true         1.0               Thiamylal
# 144569  DB01157  DOID_10763      true         1.0            Trimetrexate
# 144706  DB01158  DOID_10763      true         1.0               Bretylium
# 144843  DB01159  DOID_10763      true         1.0               Halothane
# 144980  DB01160  DOID_10763      true         1.0  Dinoprost Tromethamine
# 145117  DB01161  DOID_10763      true         1.0          Chloroprocaine
# 145391  DB01169  DOID_10763      true         1.0        Arsenic trioxide
# 146076  DB01180  DOID_10763      true         1.0            Rescinnamine
# 146213  DB01182  DOID_10763      true         1.0             Propafenone
# 146350  DB01183  DOID_10763      true         1.0                Naloxone
# 146487  DB01184  DOID_10763      true         1.0             Domperidone
# 146761  DB01189  DOID_10763      true         1.0              Desflurane
# 146898  DB01191  DOID_10763      true         1.0         Dexfenfluramine
# 147446  DB01201  DOID_10763      true         1.0             Rifapentine
# 148131  DB01211  DOID_10763      true         1.0          Clarithromycin
# 148542  DB01215  DOID_10763      true         1.0               Estazolam
# 143884  DB01146  DOID_10763      true         1.0        Diphenylpyraline
# 143473  DB01140  DOID_10763      true         1.0              Cefadroxil
# 148953  DB01220  DOID_10763      true         1.0               Rifaximin
# 143336  DB01138  DOID_10763      true         1.0          Sulfinpyrazone
# 136897  DB01058  DOID_10763      true         1.0            Praziquantel
# 137171  DB01060  DOID_10763      true         1.0             Amoxicillin
# 137856  DB01071  DOID_10763      true         1.0             Mequitazine
# 137993  DB01072  DOID_10763      true         1.0              Atazanavir
# 138815  DB01086  DOID_10763      true         1.0              Benzocaine
# ...         ...         ...       ...         ...                     ...
# 81960   DB00167  DOID_10763      true         1.0            L-Isoleucine
# 82097   DB00168  DOID_10763      true         1.0               Aspartame
# 82234   DB00170  DOID_10763      true         1.0               Menadione
# 82371   DB00171  DOID_10763      true         1.0  Adenosine triphosphate
# 82508   DB00172  DOID_10763      true         1.0               L-Proline
# 82782   DB00174  DOID_10763      true         1.0            L-Asparagine
# 82919   DB00179  DOID_10763      true         1.0              Masoprocol
# 79220   DB00144  DOID_10763      true         1.0      Phosphatidylserine
# 78535   DB00138  DOID_10763      true         1.0               L-Cystine
# 78398   DB00137  DOID_10763      true         1.0             Xanthophyll
# 75521   DB00035  DOID_10763      true         1.0            Desmopressin
# 72918   DB01398  DOID_10763      true         1.0       Salicylate-sodium
# 73055   DB00936  DOID_10763      true         1.0          Salicylic acid
# 74014   DB00408  DOID_10763      true         1.0                Loxapine
# 74425   DB00679  DOID_10763      true         1.0            Thioridazine
# 74562   DB01623  DOID_10763      true         1.0             Thiothixene
# 74836   DB01166  DOID_10763      true         1.0              Cilostazol
# 74973   DB01240  DOID_10763      true         1.0            Epoprostenol
# 75110   DB00820  DOID_10763      true         1.0               Tadalafil
# 75795   DB00093  DOID_10763      true         1.0             Felypressin
# 78124   DB00134  DOID_10763      true         1.0            L-Methionine
# 76206   DB00117  DOID_10763      true         1.0             L-Histidine
# 76343   DB00118  DOID_10763      true         1.0    S-Adenosylmethionine
# 76480   DB00119  DOID_10763      true         1.0            Pyruvic acid
# 76617   DB00120  DOID_10763      true         1.0         L-Phenylalanine
# 76891   DB00123  DOID_10763      true         1.0                L-Lysine
# 77028   DB00125  DOID_10763      true         1.0              L-Arginine
# 77302   DB00128  DOID_10763      true         1.0         L-Aspartic Acid
# 77439   DB00129  DOID_10763      true         1.0             L-Ornithine
# 210329  DB01593  DOID_10763      true         1.0                    Zinc
#
#                                           drug_categories  disease_name  \
# 7843    Adrenergic beta-2 Receptor Agonists|Bronchodil...  hypertension
# 143610                                  Antifungal Agents  hypertension
# 144021                                        Penicillins  hypertension
# 144158                                 Parasympatholytics  hypertension
# 144295                                  Antifungal Agents  hypertension
# 144432                                                NaN  hypertension
# 144569  Antifungal Agents|Antiprotozoal Agents|Folic A...  hypertension
# 144706  Antihypertensive Agents|Anti-Arrhythmia Agents...  hypertension
# 144843                Anesthetics, Inhalation|Anesthetics  hypertension
# 144980  Oxytocics|Abortifacient Agents, Nonsteroidal|A...  hypertension
# 145117                                 Anesthetics, Local  hypertension
# 145391           Antineoplastic Agents|Homeopathic Agents  hypertension
# 146076                                                NaN  hypertension
# 146213  Anti-Arrhythmia Agents|Voltage-Gated Sodium Ch...  hypertension
# 146350  Narcotic Antagonists|Central Nervous System De...  hypertension
# 146487                                                NaN  hypertension
# 146761                            Anesthetics, Inhalation  hypertension
# 146898  Serotonin Uptake Inhibitors|Anti-Obesity Agent...  hypertension
# 147446  Leprostatic Agents|Antibiotics, Antitubercular...  hypertension
# 148131  Anti-Bacterial Agents|Protein Synthesis Inhibi...  hypertension
# 148542                                                NaN  hypertension
# 143884                              Histamine Antagonists  hypertension
# 143473               Anti-Bacterial Agents|Cephalosporins  hypertension
# 148953      Gastrointestinal Agents|Anti-Infective Agents  hypertension
# 143336                                  Uricosuric Agents  hypertension
# 136897                                                NaN  hypertension
# 137171                  Anti-Bacterial Agents|Penicillins  hypertension
# 137856                           Histamine H1 Antagonists  hypertension
# 137993            Anti-HIV Agents|HIV Protease Inhibitors  hypertension
# 138815                                 Anesthetics, Local  hypertension
# ...                                                   ...           ...
# 81960   Dietary Supplements|Micronutrients|Amino Acids...  hypertension
# 82097   Sweetening Agents|Dietary Supplements|Micronut...  hypertension
# 82234   Vitamins|Antifibrinolytic Agents|Dietary Suppl...  hypertension
# 82371      Dietary Supplements|Micronutrients|Supplements  hypertension
# 82508   Dietary Supplements|Micronutrients|Supplements...  hypertension
# 82782   Dietary Supplements|Micronutrients|Supplements...  hypertension
# 82919   Antineoplastic Agents|Antioxidants|Cyclooxygen...  hypertension
# 79220      Dietary Supplements|Micronutrients|Supplements  hypertension
# 78535   Dietary Supplements|Micronutrients|Supplements...  hypertension
# 78398      Dietary Supplements|Micronutrients|Supplements  hypertension
# 75521        Antidiuretic Agents|Hemostatics|Renal Agents  hypertension
# 72918   Anti-Inflammatory Agents, Non-Steroidal|Salicy...  hypertension
# 73055   Antifungal Agents|Anti-Infective Agents|Kerato...  hypertension
# 74014           Antipsychotic Agents|Dopamine Antagonists  hypertension
# 74425   Antipsychotic Agents|Dopamine Antagonists|Phen...  hypertension
# 74562   Antipsychotic Agents|Dopamine Antagonists|Thio...  hypertension
# 74836   Fibrinolytic Agents|Platelet Aggregation Inhib...  hypertension
# 74973   Platelet Aggregation Inhibitors|Antihypertensi...  hypertension
# 75110   Vasodilator Agents|Phosphodiesterase 5 Inhibitors  hypertension
# 75795                 Vasoconstrictor Agents|Renal Agents  hypertension
# 78124   Dietary Supplements|Micronutrients|Amino Acids...  hypertension
# 76206   Dietary Supplements|Micronutrients|Conditional...  hypertension
# 76343      Dietary Supplements|Micronutrients|Supplements  hypertension
# 76480      Dietary Supplements|Micronutrients|Supplements  hypertension
# 76617   Dietary Supplements|Micronutrients|Amino Acids...  hypertension
# 76891   Dietary Supplements|Micronutrients|Amino Acids...  hypertension
# 77028   Dietary Supplements|Micronutrients|Conditional...  hypertension
# 77302   Dietary Supplements|Micronutrients|Supplements...  hypertension
# 77439   Dietary Supplements|Micronutrients|Supplements...  hypertension
# 210329                                     Trace Elements  hypertension
#
#        disease_pathophysiology
# 7843                idiopathic
# 143610              idiopathic
# 144021              idiopathic
# 144158              idiopathic
# 144295              idiopathic
# 144432              idiopathic
# 144569              idiopathic
# 144706              idiopathic
# 144843              idiopathic
# 144980              idiopathic
# 145117              idiopathic
# 145391              idiopathic
# 146076              idiopathic
# 146213              idiopathic
# 146350              idiopathic
# 146487              idiopathic
# 146761              idiopathic
# 146898              idiopathic
# 147446              idiopathic
# 148131              idiopathic
# 148542              idiopathic
# 143884              idiopathic
# 143473              idiopathic
# 148953              idiopathic
# 143336              idiopathic
# 136897              idiopathic
# 137171              idiopathic
# 137856              idiopathic
# 137993              idiopathic
# 138815              idiopathic
# ...                        ...
# 81960               idiopathic
# 82097               idiopathic
# 82234               idiopathic
# 82371               idiopathic
# 82508               idiopathic
# 82782               idiopathic
# 82919               idiopathic
# 79220               idiopathic
# 78535               idiopathic
# 78398               idiopathic
# 75521               idiopathic
# 72918               idiopathic
# 73055               idiopathic
# 74014               idiopathic
# 74425               idiopathic
# 74562               idiopathic
# 74836               idiopathic
# 74973               idiopathic
# 75110               idiopathic
# 75795               idiopathic
# 78124               idiopathic
# 76206               idiopathic
# 76343               idiopathic
# 76480               idiopathic
# 76617               idiopathic
# 76891               idiopathic
# 77028               idiopathic
# 77302               idiopathic
# 77439               idiopathic
# 210329              idiopathic
#
# [731 rows x 8 columns]

# %%
# 2. epilepsy DOID:1826 (25 drugs)
print('Indications: %s' % len(indications_df.query('doid_id == "DOID:1826"')))

# predictions
print('True predictions: {} ({}%)'.format(len(predictions_df.query('disease == "DOID_1826" & predicted == "true"')),round(len(predictions_df.query('disease == "DOID_1826" & predicted == "true"'))*100/len(predictions_df.query('disease == "DOID_1826"')))))

# overlap
indi = set(indications_df.query('doid_id == "DOID:1826"')[['drug']].drug)
pred = set(predictions_df.query('disease == "DOID_1826" & predicted == "true"')[['drug_name']].drug_name)
overlap = pred & indi
print('Indications predicted: {}\n'.format(len(overlap)))
#print(overlap)
#print('\nIndications not predicted: {}'.format(indi - pred))
print()
true = predictions_df.query('disease == "DOID_1826" & predicted == "true"')
print('Percentage of true predictions (P = 1): {}%'.format(round(
            100*len(true.query('prediction == 1'))/len(true)))
     )
print('Number of true predictions (P = 1): {}'.format(
            len(true.query('prediction == 1')))
     )

# overlap
indi = set(indications_df.query('doid_id == "DOID:1826"')[['drug']].drug)
pred = set(predictions_df.query('disease == "DOID_1826" & predicted == "true" & prediction == 1')[['drug_name']].drug_name)
overlap = pred & indi
print('Indications predicted: {}\n'.format(len(overlap)))
#print(overlap)
#print('\nIndications not predicted: {}'.format(indi - pred))
print()
predictions_df.query('disease == "DOID_1826" & predicted == "true" & prediction == 1.').sort_values(by= 'prediction', ascending= False)
# Out:
# Indications: 25
# True predictions: 1092 (71%)
# Indications predicted: 19
#
#
# Percentage of true predictions (P = 1): 62%
# Number of true predictions (P = 1): 679
# Indications predicted: 13
#            drug    disease predicted  prediction               drug_name  \
# 7833    DB01274  DOID_1826      true         1.0            Arformoterol
# 146340  DB01183  DOID_1826      true         1.0                Naloxone
# 144559  DB01157  DOID_1826      true         1.0            Trimetrexate
# 144696  DB01158  DOID_1826      true         1.0               Bretylium
# 144833  DB01159  DOID_1826      true         1.0               Halothane
# 144970  DB01160  DOID_1826      true         1.0  Dinoprost Tromethamine
# 145107  DB01161  DOID_1826      true         1.0          Chloroprocaine
# 145381  DB01169  DOID_1826      true         1.0        Arsenic trioxide
# 146066  DB01180  DOID_1826      true         1.0            Rescinnamine
# 146203  DB01182  DOID_1826      true         1.0             Propafenone
# 146477  DB01184  DOID_1826      true         1.0             Domperidone
# 137983  DB01072  DOID_1826      true         1.0              Atazanavir
# 146751  DB01189  DOID_1826      true         1.0              Desflurane
# 146888  DB01191  DOID_1826      true         1.0         Dexfenfluramine
# 147436  DB01201  DOID_1826      true         1.0             Rifapentine
# 148532  DB01215  DOID_1826      true         1.0               Estazolam
# 148669  DB01216  DOID_1826      true         1.0             Finasteride
# 148943  DB01220  DOID_1826      true         1.0               Rifaximin
# 149491  DB01227  DOID_1826      true         1.0    Levomethadyl Acetate
# 149628  DB01228  DOID_1826      true         1.0               Encainide
# 144422  DB01154  DOID_1826      true         1.0               Thiamylal
# 144285  DB01153  DOID_1826      true         1.0           Sertaconazole
# 144148  DB01148  DOID_1826      true         1.0               Flavoxate
# 144011  DB01147  DOID_1826      true         1.0             Cloxacillin
# 139079  DB01088  DOID_1826      true         1.0                Iloprost
# 139216  DB01089  DOID_1826      true         1.0             Deserpidine
# 139764  DB01093  DOID_1826      true         1.0      Dimethyl sulfoxide
# 139901  DB01094  DOID_1826      true         1.0              Hesperetin
# 140175  DB01096  DOID_1826      true         1.0             Oxamniquine
# 140449  DB01102  DOID_1826      true         1.0              Arbutamine
# ...         ...        ...       ...         ...                     ...
# 82361   DB00171  DOID_1826      true         1.0  Adenosine triphosphate
# 82498   DB00172  DOID_1826      true         1.0               L-Proline
# 82772   DB00174  DOID_1826      true         1.0            L-Asparagine
# 82909   DB00179  DOID_1826      true         1.0              Masoprocol
# 83046   DB00183  DOID_1826      true         1.0            Pentagastrin
# 83183   DB00185  DOID_1826      true         1.0              Cevimeline
# 83594   DB00194  DOID_1826      true         1.0              Vidarabine
# 83731   DB00196  DOID_1826      true         1.0             Fluconazole
# 80306   DB00152  DOID_1826      true         1.0                Thiamine
# 80032   DB00150  DOID_1826      true         1.0            L-Tryptophan
# 74826   DB01166  DOID_1826      true         1.0              Cilostazol
# 79895   DB00149  DOID_1826      true         1.0               L-Leucine
# 74963   DB01240  DOID_1826      true         1.0            Epoprostenol
# 75100   DB00820  DOID_1826      true         1.0               Tadalafil
# 75785   DB00093  DOID_1826      true         1.0             Felypressin
# 76196   DB00117  DOID_1826      true         1.0             L-Histidine
# 76333   DB00118  DOID_1826      true         1.0    S-Adenosylmethionine
# 76470   DB00119  DOID_1826      true         1.0            Pyruvic acid
# 76607   DB00120  DOID_1826      true         1.0         L-Phenylalanine
# 76881   DB00123  DOID_1826      true         1.0                L-Lysine
# 77018   DB00125  DOID_1826      true         1.0              L-Arginine
# 77292   DB00128  DOID_1826      true         1.0         L-Aspartic Acid
# 77429   DB00129  DOID_1826      true         1.0             L-Ornithine
# 78114   DB00134  DOID_1826      true         1.0            L-Methionine
# 78388   DB00137  DOID_1826      true         1.0             Xanthophyll
# 78525   DB00138  DOID_1826      true         1.0               L-Cystine
# 79210   DB00144  DOID_1826      true         1.0      Phosphatidylserine
# 79347   DB00145  DOID_1826      true         1.0                 Glycine
# 79758   DB00148  DOID_1826      true         1.0                Creatine
# 210319  DB01593  DOID_1826      true         1.0                    Zinc
#
#                                           drug_categories       disease_name  \
# 7833    Adrenergic beta-2 Receptor Agonists|Bronchodil...  epilepsy syndrome
# 146340  Narcotic Antagonists|Central Nervous System De...  epilepsy syndrome
# 144559  Antifungal Agents|Antiprotozoal Agents|Folic A...  epilepsy syndrome
# 144696  Antihypertensive Agents|Anti-Arrhythmia Agents...  epilepsy syndrome
# 144833                Anesthetics, Inhalation|Anesthetics  epilepsy syndrome
# 144970  Oxytocics|Abortifacient Agents, Nonsteroidal|A...  epilepsy syndrome
# 145107                                 Anesthetics, Local  epilepsy syndrome
# 145381           Antineoplastic Agents|Homeopathic Agents  epilepsy syndrome
# 146066                                                NaN  epilepsy syndrome
# 146203  Anti-Arrhythmia Agents|Voltage-Gated Sodium Ch...  epilepsy syndrome
# 146477                                                NaN  epilepsy syndrome
# 137983            Anti-HIV Agents|HIV Protease Inhibitors  epilepsy syndrome
# 146751                            Anesthetics, Inhalation  epilepsy syndrome
# 146888  Serotonin Uptake Inhibitors|Anti-Obesity Agent...  epilepsy syndrome
# 147436  Leprostatic Agents|Antibiotics, Antitubercular...  epilepsy syndrome
# 148532                                                NaN  epilepsy syndrome
# 148669  5-alpha Reductase Inhibitors|Skin and Mucous M...  epilepsy syndrome
# 148943      Gastrointestinal Agents|Anti-Infective Agents  epilepsy syndrome
# 149491                       Analgesics, Opioid|Narcotics  epilepsy syndrome
# 149628  Anti-Arrhythmia Agents|Voltage-Gated Sodium Ch...  epilepsy syndrome
# 144422                                                NaN  epilepsy syndrome
# 144285                                  Antifungal Agents  epilepsy syndrome
# 144148                                 Parasympatholytics  epilepsy syndrome
# 144011                                        Penicillins  epilepsy syndrome
# 139079                                                NaN  epilepsy syndrome
# 139216                                                NaN  epilepsy syndrome
# 139764  Free Radical Scavengers|Solvents|Cryoprotectiv...  epilepsy syndrome
# 139901                                                NaN  epilepsy syndrome
# 140175                                                NaN  epilepsy syndrome
# 140449                                                NaN  epilepsy syndrome
# ...                                                   ...                ...
# 82361      Dietary Supplements|Micronutrients|Supplements  epilepsy syndrome
# 82498   Dietary Supplements|Micronutrients|Supplements...  epilepsy syndrome
# 82772   Dietary Supplements|Micronutrients|Supplements...  epilepsy syndrome
# 82909   Antineoplastic Agents|Antioxidants|Cyclooxygen...  epilepsy syndrome
# 83046                                   Diagnostic Agents  epilepsy syndrome
# 83183                                                 NaN  epilepsy syndrome
# 83594                    Antiviral Agents|Antimetabolites  epilepsy syndrome
# 83731                                   Antifungal Agents  epilepsy syndrome
# 80306                          Vitamin B Complex|Vitamins  epilepsy syndrome
# 80032   Antidepressive Agents, Second-Generation|Dieta...  epilepsy syndrome
# 74826   Fibrinolytic Agents|Platelet Aggregation Inhib...  epilepsy syndrome
# 79895   Dietary Supplements|Micronutrients|Amino Acids...  epilepsy syndrome
# 74963   Platelet Aggregation Inhibitors|Antihypertensi...  epilepsy syndrome
# 75100   Vasodilator Agents|Phosphodiesterase 5 Inhibitors  epilepsy syndrome
# 75785                 Vasoconstrictor Agents|Renal Agents  epilepsy syndrome
# 76196   Dietary Supplements|Micronutrients|Conditional...  epilepsy syndrome
# 76333      Dietary Supplements|Micronutrients|Supplements  epilepsy syndrome
# 76470      Dietary Supplements|Micronutrients|Supplements  epilepsy syndrome
# 76607   Dietary Supplements|Micronutrients|Amino Acids...  epilepsy syndrome
# 76881   Dietary Supplements|Micronutrients|Amino Acids...  epilepsy syndrome
# 77018   Dietary Supplements|Micronutrients|Conditional...  epilepsy syndrome
# 77292   Dietary Supplements|Micronutrients|Supplements...  epilepsy syndrome
# 77429   Dietary Supplements|Micronutrients|Supplements...  epilepsy syndrome
# 78114   Dietary Supplements|Micronutrients|Amino Acids...  epilepsy syndrome
# 78388      Dietary Supplements|Micronutrients|Supplements  epilepsy syndrome
# 78525   Dietary Supplements|Micronutrients|Supplements...  epilepsy syndrome
# 79210      Dietary Supplements|Micronutrients|Supplements  epilepsy syndrome
# 79347   Glycine Agents|Dietary Supplements|Micronutrie...  epilepsy syndrome
# 79758      Dietary Supplements|Micronutrients|Supplements  epilepsy syndrome
# 210319                                     Trace Elements  epilepsy syndrome
#
#        disease_pathophysiology
# 7833                unspecific
# 146340              unspecific
# 144559              unspecific
# 144696              unspecific
# 144833              unspecific
# 144970              unspecific
# 145107              unspecific
# 145381              unspecific
# 146066              unspecific
# 146203              unspecific
# 146477              unspecific
# 137983              unspecific
# 146751              unspecific
# 146888              unspecific
# 147436              unspecific
# 148532              unspecific
# 148669              unspecific
# 148943              unspecific
# 149491              unspecific
# 149628              unspecific
# 144422              unspecific
# 144285              unspecific
# 144148              unspecific
# 144011              unspecific
# 139079              unspecific
# 139216              unspecific
# 139764              unspecific
# 139901              unspecific
# 140175              unspecific
# 140449              unspecific
# ...                        ...
# 82361               unspecific
# 82498               unspecific
# 82772               unspecific
# 82909               unspecific
# 83046               unspecific
# 83183               unspecific
# 83594               unspecific
# 83731               unspecific
# 80306               unspecific
# 80032               unspecific
# 74826               unspecific
# 79895               unspecific
# 74963               unspecific
# 75100               unspecific
# 75785               unspecific
# 76196               unspecific
# 76333               unspecific
# 76470               unspecific
# 76607               unspecific
# 76881               unspecific
# 77018               unspecific
# 77292               unspecific
# 77429               unspecific
# 78114               unspecific
# 78388               unspecific
# 78525               unspecific
# 79210               unspecific
# 79347               unspecific
# 79758               unspecific
# 210319              unspecific
#
# [679 rows x 8 columns]

# %%
# 3. malaria DOID:12365 (11 drugs)
print('Indications: %s' % len(indications_df.query('doid_id == "DOID:12365"')))

# predictions
print('True predictions: {} ({}%)'.format(len(predictions_df.query('disease == "DOID_12365" & predicted == "true"')),round(len(predictions_df.query('disease == "DOID_12365" & predicted == "true"'))*100/len(predictions_df.query('disease == "DOID_12365"')))))

# overlap
indi = set(indications_df.query('doid_id == "DOID:12365"')[['drug']].drug)
pred = set(predictions_df.query('disease == "DOID_12365" & predicted == "true"')[['drug_name']].drug_name)
overlap = pred & indi
print('Indications predicted: {}\n'.format(len(overlap)))
#print(overlap)
#print('\nIndications not predicted: {}'.format(indi - pred))
print()
true = predictions_df.query('disease == "DOID_12365" & predicted == "true"')
print('Percentage of true predictions (P = 1): {}%'.format(round(
            100*len(true.query('prediction == 1'))/len(true)))
     )
print('Number of true predictions (P = 1): {}'.format(
            len(true.query('prediction == 1')))
     )

# overlap
indi = set(indications_df.query('doid_id == "DOID:12365"')[['drug']].drug)
pred = set(predictions_df.query('disease == "DOID_12365" & predicted == "true" & prediction == 1.')[['drug_name']].drug_name)
overlap = pred & indi
print('Indications predicted: {}\n'.format(len(overlap)))
#print(overlap)
#print('\nIndications not predicted: {}'.format(indi - pred))
print()
predictions_df.query('disease == "DOID_12365" & predicted == "true" & prediction == 1.').sort_values(by= 'prediction', ascending= False)
# Out:
# Indications: 11
# True predictions: 987 (64%)
# Indications predicted: 11
#
#
# Percentage of true predictions (P = 1): 58%
# Number of true predictions (P = 1): 571
# Indications predicted: 6
#            drug     disease predicted  prediction               drug_name  \
# 8398    DB01003  DOID_12365      true         1.0        Cromoglicic acid
# 146083  DB01180  DOID_12365      true         1.0            Rescinnamine
# 144439  DB01154  DOID_12365      true         1.0               Thiamylal
# 144713  DB01158  DOID_12365      true         1.0               Bretylium
# 144850  DB01159  DOID_12365      true         1.0               Halothane
# 144987  DB01160  DOID_12365      true         1.0  Dinoprost Tromethamine
# 145124  DB01161  DOID_12365      true         1.0          Chloroprocaine
# 145398  DB01169  DOID_12365      true         1.0        Arsenic trioxide
# 146220  DB01182  DOID_12365      true         1.0             Propafenone
# 144028  DB01147  DOID_12365      true         1.0             Cloxacillin
# 146357  DB01183  DOID_12365      true         1.0                Naloxone
# 146494  DB01184  DOID_12365      true         1.0             Domperidone
# 146768  DB01189  DOID_12365      true         1.0              Desflurane
# 147453  DB01201  DOID_12365      true         1.0             Rifapentine
# 148549  DB01215  DOID_12365      true         1.0               Estazolam
# 148686  DB01216  DOID_12365      true         1.0             Finasteride
# 144165  DB01148  DOID_12365      true         1.0               Flavoxate
# 143891  DB01146  DOID_12365      true         1.0        Diphenylpyraline
# 149508  DB01227  DOID_12365      true         1.0    Levomethadyl Acetate
# 140466  DB01102  DOID_12365      true         1.0              Arbutamine
# 138822  DB01086  DOID_12365      true         1.0              Benzocaine
# 139096  DB01088  DOID_12365      true         1.0                Iloprost
# 139233  DB01089  DOID_12365      true         1.0             Deserpidine
# 139781  DB01093  DOID_12365      true         1.0      Dimethyl sulfoxide
# 139918  DB01094  DOID_12365      true         1.0              Hesperetin
# 140192  DB01096  DOID_12365      true         1.0             Oxamniquine
# 141151  DB01110  DOID_12365      true         1.0              Miconazole
# 143617  DB01141  DOID_12365      true         1.0              Micafungin
# 141562  DB01114  DOID_12365      true         1.0          Chlorphenamine
# 141836  DB01117  DOID_12365      true         1.0              Atovaquone
# ...         ...         ...       ...         ...                     ...
# 80186   DB00151  DOID_12365      true         1.0              L-Cysteine
# 80323   DB00152  DOID_12365      true         1.0                Thiamine
# 80597   DB00155  DOID_12365      true         1.0            L-Citrulline
# 80734   DB00156  DOID_12365      true         1.0             L-Threonine
# 81693   DB00165  DOID_12365      true         1.0              Pyridoxine
# 72925   DB01398  DOID_12365      true         1.0       Salicylate-sodium
# 81967   DB00167  DOID_12365      true         1.0            L-Isoleucine
# 82104   DB00168  DOID_12365      true         1.0               Aspartame
# 82241   DB00170  DOID_12365      true         1.0               Menadione
# 82378   DB00171  DOID_12365      true         1.0  Adenosine triphosphate
# 82515   DB00172  DOID_12365      true         1.0               L-Proline
# 82789   DB00174  DOID_12365      true         1.0            L-Asparagine
# 79775   DB00148  DOID_12365      true         1.0                Creatine
# 79227   DB00144  DOID_12365      true         1.0      Phosphatidylserine
# 78542   DB00138  DOID_12365      true         1.0               L-Cystine
# 78405   DB00137  DOID_12365      true         1.0             Xanthophyll
# 78131   DB00134  DOID_12365      true         1.0            L-Methionine
# 77446   DB00129  DOID_12365      true         1.0             L-Ornithine
# 76898   DB00123  DOID_12365      true         1.0                L-Lysine
# 76624   DB00120  DOID_12365      true         1.0         L-Phenylalanine
# 76487   DB00119  DOID_12365      true         1.0            Pyruvic acid
# 76350   DB00118  DOID_12365      true         1.0    S-Adenosylmethionine
# 76213   DB00117  DOID_12365      true         1.0             L-Histidine
# 75802   DB00093  DOID_12365      true         1.0             Felypressin
# 75117   DB00820  DOID_12365      true         1.0               Tadalafil
# 74980   DB01240  DOID_12365      true         1.0            Epoprostenol
# 74843   DB01166  DOID_12365      true         1.0              Cilostazol
# 74569   DB01623  DOID_12365      true         1.0             Thiothixene
# 73062   DB00936  DOID_12365      true         1.0          Salicylic acid
# 210336  DB01593  DOID_12365      true         1.0                    Zinc
#
#                                           drug_categories disease_name  \
# 8398                                Anti-Asthmatic Agents      malaria
# 146083                                                NaN      malaria
# 144439                                                NaN      malaria
# 144713  Antihypertensive Agents|Anti-Arrhythmia Agents...      malaria
# 144850                Anesthetics, Inhalation|Anesthetics      malaria
# 144987  Oxytocics|Abortifacient Agents, Nonsteroidal|A...      malaria
# 145124                                 Anesthetics, Local      malaria
# 145398           Antineoplastic Agents|Homeopathic Agents      malaria
# 146220  Anti-Arrhythmia Agents|Voltage-Gated Sodium Ch...      malaria
# 144028                                        Penicillins      malaria
# 146357  Narcotic Antagonists|Central Nervous System De...      malaria
# 146494                                                NaN      malaria
# 146768                            Anesthetics, Inhalation      malaria
# 147453  Leprostatic Agents|Antibiotics, Antitubercular...      malaria
# 148549                                                NaN      malaria
# 148686  5-alpha Reductase Inhibitors|Skin and Mucous M...      malaria
# 144165                                 Parasympatholytics      malaria
# 143891                              Histamine Antagonists      malaria
# 149508                       Analgesics, Opioid|Narcotics      malaria
# 140466                                                NaN      malaria
# 138822                                 Anesthetics, Local      malaria
# 139096                                                NaN      malaria
# 139233                                                NaN      malaria
# 139781  Free Radical Scavengers|Solvents|Cryoprotectiv...      malaria
# 139918                                                NaN      malaria
# 140192                                                NaN      malaria
# 141151  Antifungal Agents|14-alpha Demethylase Inhibitors      malaria
# 143617                                  Antifungal Agents      malaria
# 141562     Histamine H1 Antagonists|Histamine Antagonists      malaria
# 141836                                                NaN      malaria
# ...                                                   ...          ...
# 80186   Dietary Supplements|Nutritional Support|Supple...      malaria
# 80323                          Vitamin B Complex|Vitamins      malaria
# 80597   Dietary Supplements|Micronutrients|Supplements...      malaria
# 80734   Dietary Supplements|Micronutrients|Amino Acids...      malaria
# 81693                          Vitamin B Complex|Vitamins      malaria
# 72925   Anti-Inflammatory Agents, Non-Steroidal|Salicy...      malaria
# 81967   Dietary Supplements|Micronutrients|Amino Acids...      malaria
# 82104   Sweetening Agents|Dietary Supplements|Micronut...      malaria
# 82241   Vitamins|Antifibrinolytic Agents|Dietary Suppl...      malaria
# 82378      Dietary Supplements|Micronutrients|Supplements      malaria
# 82515   Dietary Supplements|Micronutrients|Supplements...      malaria
# 82789   Dietary Supplements|Micronutrients|Supplements...      malaria
# 79775      Dietary Supplements|Micronutrients|Supplements      malaria
# 79227      Dietary Supplements|Micronutrients|Supplements      malaria
# 78542   Dietary Supplements|Micronutrients|Supplements...      malaria
# 78405      Dietary Supplements|Micronutrients|Supplements      malaria
# 78131   Dietary Supplements|Micronutrients|Amino Acids...      malaria
# 77446   Dietary Supplements|Micronutrients|Supplements...      malaria
# 76898   Dietary Supplements|Micronutrients|Amino Acids...      malaria
# 76624   Dietary Supplements|Micronutrients|Amino Acids...      malaria
# 76487      Dietary Supplements|Micronutrients|Supplements      malaria
# 76350      Dietary Supplements|Micronutrients|Supplements      malaria
# 76213   Dietary Supplements|Micronutrients|Conditional...      malaria
# 75802                 Vasoconstrictor Agents|Renal Agents      malaria
# 75117   Vasodilator Agents|Phosphodiesterase 5 Inhibitors      malaria
# 74980   Platelet Aggregation Inhibitors|Antihypertensi...      malaria
# 74843   Fibrinolytic Agents|Platelet Aggregation Inhib...      malaria
# 74569   Antipsychotic Agents|Dopamine Antagonists|Thio...      malaria
# 73062   Antifungal Agents|Anti-Infective Agents|Kerato...      malaria
# 210336                                     Trace Elements      malaria
#
#        disease_pathophysiology
# 8398                infectious
# 146083              infectious
# 144439              infectious
# 144713              infectious
# 144850              infectious
# 144987              infectious
# 145124              infectious
# 145398              infectious
# 146220              infectious
# 144028              infectious
# 146357              infectious
# 146494              infectious
# 146768              infectious
# 147453              infectious
# 148549              infectious
# 148686              infectious
# 144165              infectious
# 143891              infectious
# 149508              infectious
# 140466              infectious
# 138822              infectious
# 139096              infectious
# 139233              infectious
# 139781              infectious
# 139918              infectious
# 140192              infectious
# 141151              infectious
# 143617              infectious
# 141562              infectious
# 141836              infectious
# ...                        ...
# 80186               infectious
# 80323               infectious
# 80597               infectious
# 80734               infectious
# 81693               infectious
# 72925               infectious
# 81967               infectious
# 82104               infectious
# 82241               infectious
# 82378               infectious
# 82515               infectious
# 82789               infectious
# 79775               infectious
# 79227               infectious
# 78542               infectious
# 78405               infectious
# 78131               infectious
# 77446               infectious
# 76898               infectious
# 76624               infectious
# 76487               infectious
# 76350               infectious
# 76213               infectious
# 75802               infectious
# 75117               infectious
# 74980               infectious
# 74843               infectious
# 74569               infectious
# 73062               infectious
# 210336              infectious
#
# [571 rows x 8 columns]

# %%
# 4. thyroid cancer DOID:1781 (4 drugs)
print('Indications: %s' % len(indications_df.query('doid_id == "DOID:1781"')))

# predictions
print('True predictions: {} ({}%)'.format(len(predictions_df.query('disease == "DOID_1781" & predicted == "true"')),round(len(predictions_df.query('disease == "DOID_1781" & predicted == "true"'))*100/len(predictions_df.query('disease == "DOID_1781"')))))

# overlap
indi = set(indications_df.query('doid_id == "DOID:1781"')[['drug']].drug)
pred = set(predictions_df.query('disease == "DOID_1781" & predicted == "true"')[['drug_name']].drug_name)
overlap = pred & indi
print('Indications predicted: {}\n'.format(len(overlap)))
#print(overlap)
#print('\nIndications not predicted: {}'.format(indi - pred))
print()
true = predictions_df.query('disease == "DOID_1781" & predicted == "true"')
print('Percentage of true predictions (P = 1): {}%'.format(round(
            100*len(true.query('prediction == 1'))/len(true)))
     )
print('Number of true predictions (P = 1): {}'.format(
            len(true.query('prediction == 1')))
     )

# overlap
indi = set(indications_df.query('doid_id == "DOID:1781"')[['drug']].drug)
pred = set(predictions_df.query('disease == "DOID_1781" & predicted == "true" & prediction == 1.')[['drug_name']].drug_name)
overlap = pred & indi
print('Indications predicted: {}\n'.format(len(overlap)))
#print(overlap)
#print('\nIndications not predicted: {}'.format(indi - pred))
print()
predictions_df.query('disease == "DOID_1781" & predicted == "true" & prediction == 1.').sort_values(by= 'prediction', ascending= False)
# Out:
# Indications: 4
# True predictions: 964 (63%)
# Indications predicted: 4
#
#
# Percentage of true predictions (P = 1): 58%
# Number of true predictions (P = 1): 555
# Indications predicted: 1
#            drug    disease predicted  prediction               drug_name  \
# 8427    DB01003  DOID_1781      true         1.0        Cromoglicic acid
# 146112  DB01180  DOID_1781      true         1.0            Rescinnamine
# 144468  DB01154  DOID_1781      true         1.0               Thiamylal
# 144742  DB01158  DOID_1781      true         1.0               Bretylium
# 144879  DB01159  DOID_1781      true         1.0               Halothane
# 145016  DB01160  DOID_1781      true         1.0  Dinoprost Tromethamine
# 145153  DB01161  DOID_1781      true         1.0          Chloroprocaine
# 145427  DB01169  DOID_1781      true         1.0        Arsenic trioxide
# 146249  DB01182  DOID_1781      true         1.0             Propafenone
# 149537  DB01227  DOID_1781      true         1.0    Levomethadyl Acetate
# 146386  DB01183  DOID_1781      true         1.0                Naloxone
# 146523  DB01184  DOID_1781      true         1.0             Domperidone
# 146797  DB01189  DOID_1781      true         1.0              Desflurane
# 147482  DB01201  DOID_1781      true         1.0             Rifapentine
# 148578  DB01215  DOID_1781      true         1.0               Estazolam
# 148715  DB01216  DOID_1781      true         1.0             Finasteride
# 144194  DB01148  DOID_1781      true         1.0               Flavoxate
# 144057  DB01147  DOID_1781      true         1.0             Cloxacillin
# 143920  DB01146  DOID_1781      true         1.0        Diphenylpyraline
# 143646  DB01141  DOID_1781      true         1.0              Micafungin
# 143509  DB01140  DOID_1781      true         1.0              Cefadroxil
# 143372  DB01138  DOID_1781      true         1.0          Sulfinpyrazone
# 142824  DB01127  DOID_1781      true         1.0               Econazole
# 142687  DB01126  DOID_1781      true         1.0             Dutasteride
# 141865  DB01117  DOID_1781      true         1.0              Atovaquone
# 141591  DB01114  DOID_1781      true         1.0          Chlorphenamine
# 141180  DB01110  DOID_1781      true         1.0              Miconazole
# 140495  DB01102  DOID_1781      true         1.0              Arbutamine
# 140221  DB01096  DOID_1781      true         1.0             Oxamniquine
# 139947  DB01094  DOID_1781      true         1.0              Hesperetin
# ...         ...        ...       ...         ...                     ...
# 83229   DB00185  DOID_1781      true         1.0              Cevimeline
# 83092   DB00183  DOID_1781      true         1.0            Pentagastrin
# 82818   DB00174  DOID_1781      true         1.0            L-Asparagine
# 82544   DB00172  DOID_1781      true         1.0               L-Proline
# 82270   DB00170  DOID_1781      true         1.0               Menadione
# 82133   DB00168  DOID_1781      true         1.0               Aspartame
# 81996   DB00167  DOID_1781      true         1.0            L-Isoleucine
# 81722   DB00165  DOID_1781      true         1.0              Pyridoxine
# 81174   DB00160  DOID_1781      true         1.0               L-Alanine
# 80763   DB00156  DOID_1781      true         1.0             L-Threonine
# 80626   DB00155  DOID_1781      true         1.0            L-Citrulline
# 80352   DB00152  DOID_1781      true         1.0                Thiamine
# 80215   DB00151  DOID_1781      true         1.0              L-Cysteine
# 79941   DB00149  DOID_1781      true         1.0               L-Leucine
# 74872   DB01166  DOID_1781      true         1.0              Cilostazol
# 79804   DB00148  DOID_1781      true         1.0                Creatine
# 79256   DB00144  DOID_1781      true         1.0      Phosphatidylserine
# 78571   DB00138  DOID_1781      true         1.0               L-Cystine
# 78434   DB00137  DOID_1781      true         1.0             Xanthophyll
# 78160   DB00134  DOID_1781      true         1.0            L-Methionine
# 77475   DB00129  DOID_1781      true         1.0             L-Ornithine
# 76927   DB00123  DOID_1781      true         1.0                L-Lysine
# 76653   DB00120  DOID_1781      true         1.0         L-Phenylalanine
# 76516   DB00119  DOID_1781      true         1.0            Pyruvic acid
# 76379   DB00118  DOID_1781      true         1.0    S-Adenosylmethionine
# 76242   DB00117  DOID_1781      true         1.0             L-Histidine
# 75831   DB00093  DOID_1781      true         1.0             Felypressin
# 75146   DB00820  DOID_1781      true         1.0               Tadalafil
# 75009   DB01240  DOID_1781      true         1.0            Epoprostenol
# 210365  DB01593  DOID_1781      true         1.0                    Zinc
#
#                                           drug_categories    disease_name  \
# 8427                                Anti-Asthmatic Agents  thyroid cancer
# 146112                                                NaN  thyroid cancer
# 144468                                                NaN  thyroid cancer
# 144742  Antihypertensive Agents|Anti-Arrhythmia Agents...  thyroid cancer
# 144879                Anesthetics, Inhalation|Anesthetics  thyroid cancer
# 145016  Oxytocics|Abortifacient Agents, Nonsteroidal|A...  thyroid cancer
# 145153                                 Anesthetics, Local  thyroid cancer
# 145427           Antineoplastic Agents|Homeopathic Agents  thyroid cancer
# 146249  Anti-Arrhythmia Agents|Voltage-Gated Sodium Ch...  thyroid cancer
# 149537                       Analgesics, Opioid|Narcotics  thyroid cancer
# 146386  Narcotic Antagonists|Central Nervous System De...  thyroid cancer
# 146523                                                NaN  thyroid cancer
# 146797                            Anesthetics, Inhalation  thyroid cancer
# 147482  Leprostatic Agents|Antibiotics, Antitubercular...  thyroid cancer
# 148578                                                NaN  thyroid cancer
# 148715  5-alpha Reductase Inhibitors|Skin and Mucous M...  thyroid cancer
# 144194                                 Parasympatholytics  thyroid cancer
# 144057                                        Penicillins  thyroid cancer
# 143920                              Histamine Antagonists  thyroid cancer
# 143646                                  Antifungal Agents  thyroid cancer
# 143509               Anti-Bacterial Agents|Cephalosporins  thyroid cancer
# 143372                                  Uricosuric Agents  thyroid cancer
# 142824                                                NaN  thyroid cancer
# 142687                                                NaN  thyroid cancer
# 141865                                                NaN  thyroid cancer
# 141591     Histamine H1 Antagonists|Histamine Antagonists  thyroid cancer
# 141180  Antifungal Agents|14-alpha Demethylase Inhibitors  thyroid cancer
# 140495                                                NaN  thyroid cancer
# 140221                                                NaN  thyroid cancer
# 139947                                                NaN  thyroid cancer
# ...                                                   ...             ...
# 83229                                                 NaN  thyroid cancer
# 83092                                   Diagnostic Agents  thyroid cancer
# 82818   Dietary Supplements|Micronutrients|Supplements...  thyroid cancer
# 82544   Dietary Supplements|Micronutrients|Supplements...  thyroid cancer
# 82270   Vitamins|Antifibrinolytic Agents|Dietary Suppl...  thyroid cancer
# 82133   Sweetening Agents|Dietary Supplements|Micronut...  thyroid cancer
# 81996   Dietary Supplements|Micronutrients|Amino Acids...  thyroid cancer
# 81722                          Vitamin B Complex|Vitamins  thyroid cancer
# 81174   Dietary Supplements|Micronutrients|Supplements...  thyroid cancer
# 80763   Dietary Supplements|Micronutrients|Amino Acids...  thyroid cancer
# 80626   Dietary Supplements|Micronutrients|Supplements...  thyroid cancer
# 80352                          Vitamin B Complex|Vitamins  thyroid cancer
# 80215   Dietary Supplements|Nutritional Support|Supple...  thyroid cancer
# 79941   Dietary Supplements|Micronutrients|Amino Acids...  thyroid cancer
# 74872   Fibrinolytic Agents|Platelet Aggregation Inhib...  thyroid cancer
# 79804      Dietary Supplements|Micronutrients|Supplements  thyroid cancer
# 79256      Dietary Supplements|Micronutrients|Supplements  thyroid cancer
# 78571   Dietary Supplements|Micronutrients|Supplements...  thyroid cancer
# 78434      Dietary Supplements|Micronutrients|Supplements  thyroid cancer
# 78160   Dietary Supplements|Micronutrients|Amino Acids...  thyroid cancer
# 77475   Dietary Supplements|Micronutrients|Supplements...  thyroid cancer
# 76927   Dietary Supplements|Micronutrients|Amino Acids...  thyroid cancer
# 76653   Dietary Supplements|Micronutrients|Amino Acids...  thyroid cancer
# 76516      Dietary Supplements|Micronutrients|Supplements  thyroid cancer
# 76379      Dietary Supplements|Micronutrients|Supplements  thyroid cancer
# 76242   Dietary Supplements|Micronutrients|Conditional...  thyroid cancer
# 75831                 Vasoconstrictor Agents|Renal Agents  thyroid cancer
# 75146   Vasodilator Agents|Phosphodiesterase 5 Inhibitors  thyroid cancer
# 75009   Platelet Aggregation Inhibitors|Antihypertensi...  thyroid cancer
# 210365                                     Trace Elements  thyroid cancer
#
#        disease_pathophysiology
# 8427                neoplastic
# 146112              neoplastic
# 144468              neoplastic
# 144742              neoplastic
# 144879              neoplastic
# 145016              neoplastic
# 145153              neoplastic
# 145427              neoplastic
# 146249              neoplastic
# 149537              neoplastic
# 146386              neoplastic
# 146523              neoplastic
# 146797              neoplastic
# 147482              neoplastic
# 148578              neoplastic
# 148715              neoplastic
# 144194              neoplastic
# 144057              neoplastic
# 143920              neoplastic
# 143646              neoplastic
# 143509              neoplastic
# 143372              neoplastic
# 142824              neoplastic
# 142687              neoplastic
# 141865              neoplastic
# 141591              neoplastic
# 141180              neoplastic
# 140495              neoplastic
# 140221              neoplastic
# 139947              neoplastic
# ...                        ...
# 83229               neoplastic
# 83092               neoplastic
# 82818               neoplastic
# 82544               neoplastic
# 82270               neoplastic
# 82133               neoplastic
# 81996               neoplastic
# 81722               neoplastic
# 81174               neoplastic
# 80763               neoplastic
# 80626               neoplastic
# 80352               neoplastic
# 80215               neoplastic
# 79941               neoplastic
# 74872               neoplastic
# 79804               neoplastic
# 79256               neoplastic
# 78571               neoplastic
# 78434               neoplastic
# 78160               neoplastic
# 77475               neoplastic
# 76927               neoplastic
# 76653               neoplastic
# 76516               neoplastic
# 76379               neoplastic
# 76242               neoplastic
# 75831               neoplastic
# 75146               neoplastic
# 75009               neoplastic
# 210365              neoplastic
#
# [555 rows x 8 columns]

# %%
# 5. obesity DOID:9970 (11 drugs)
print('Indications: %s' % len(indications_df.query('doid_id == "DOID:9970"')))

# predictions
print('True predictions: {} ({}%)'.format(len(predictions_df.query('disease == "DOID_9970" & predicted == "true"')),round(len(predictions_df.query('disease == "DOID_9970" & predicted == "true"'))*100/len(predictions_df.query('disease == "DOID_9970"')))))

# overlap
indi = set(indications_df.query('doid_id == "DOID:9970"')[['drug']].drug)
pred = set(predictions_df.query('disease == "DOID_9970" & predicted == "true"')[['drug_name']].drug_name)
overlap = pred & indi
print('Indications predicted: {}\n'.format(len(overlap)))
#print(overlap)
#print('\nIndications not predicted: {}'.format(indi - pred))
print()
true = predictions_df.query('disease == "DOID_9970" & predicted == "true"')
print('Percentage of true predictions (P = 1): {}%'.format(round(
            100*len(true.query('prediction == 1'))/len(true)))
     )
print('Number of true predictions (P = 1): {}'.format(
            len(true.query('prediction == 1')))
     )

# overlap
indi = set(indications_df.query('doid_id == "DOID:9970"')[['drug']].drug)
pred = set(predictions_df.query('disease == "DOID_9970" & predicted == "true" & prediction == 1.')[['drug_name']].drug_name)
overlap = pred & indi
print('Indications predicted: {}\n'.format(len(overlap)))
#print(overlap)
#print('\nIndications not predicted: {}'.format(indi - pred))
print()
predictions_df.query('disease == "DOID_9970" & predicted == "true" & prediction == 1.').sort_values(by= 'prediction', ascending= False)
# Out:
# Indications: 11
# True predictions: 1062 (69%)
# Indications predicted: 8
#
#
# Percentage of true predictions (P = 1): 60%
# Number of true predictions (P = 1): 642
# Indications predicted: 4
#            drug    disease predicted  prediction               drug_name  \
# 7859    DB01274  DOID_9970      true         1.0            Arformoterol
# 162532  DB01581  DOID_9970      true         1.0           Sulfamerazine
# 144448  DB01154  DOID_9970      true         1.0               Thiamylal
# 144722  DB01158  DOID_9970      true         1.0               Bretylium
# 144859  DB01159  DOID_9970      true         1.0               Halothane
# 144996  DB01160  DOID_9970      true         1.0  Dinoprost Tromethamine
# 145133  DB01161  DOID_9970      true         1.0          Chloroprocaine
# 145407  DB01169  DOID_9970      true         1.0        Arsenic trioxide
# 146092  DB01180  DOID_9970      true         1.0            Rescinnamine
# 146229  DB01182  DOID_9970      true         1.0             Propafenone
# 146366  DB01183  DOID_9970      true         1.0                Naloxone
# 146503  DB01184  DOID_9970      true         1.0             Domperidone
# 146777  DB01189  DOID_9970      true         1.0              Desflurane
# 146914  DB01191  DOID_9970      true         1.0         Dexfenfluramine
# 147462  DB01201  DOID_9970      true         1.0             Rifapentine
# 148558  DB01215  DOID_9970      true         1.0               Estazolam
# 148695  DB01216  DOID_9970      true         1.0             Finasteride
# 148969  DB01220  DOID_9970      true         1.0               Rifaximin
# 149517  DB01227  DOID_9970      true         1.0    Levomethadyl Acetate
# 144311  DB01153  DOID_9970      true         1.0           Sertaconazole
# 144174  DB01148  DOID_9970      true         1.0               Flavoxate
# 144037  DB01147  DOID_9970      true         1.0             Cloxacillin
# 141571  DB01114  DOID_9970      true         1.0          Chlorphenamine
# 139105  DB01088  DOID_9970      true         1.0                Iloprost
# 139242  DB01089  DOID_9970      true         1.0             Deserpidine
# 139790  DB01093  DOID_9970      true         1.0      Dimethyl sulfoxide
# 139927  DB01094  DOID_9970      true         1.0              Hesperetin
# 140201  DB01096  DOID_9970      true         1.0             Oxamniquine
# 140475  DB01102  DOID_9970      true         1.0              Arbutamine
# 141160  DB01110  DOID_9970      true         1.0              Miconazole
# ...         ...        ...       ...         ...                     ...
# 82387   DB00171  DOID_9970      true         1.0  Adenosine triphosphate
# 80195   DB00151  DOID_9970      true         1.0              L-Cysteine
# 82524   DB00172  DOID_9970      true         1.0               L-Proline
# 82798   DB00174  DOID_9970      true         1.0            L-Asparagine
# 82935   DB00179  DOID_9970      true         1.0              Masoprocol
# 83072   DB00183  DOID_9970      true         1.0            Pentagastrin
# 83209   DB00185  DOID_9970      true         1.0              Cevimeline
# 83620   DB00194  DOID_9970      true         1.0              Vidarabine
# 83757   DB00196  DOID_9970      true         1.0             Fluconazole
# 80332   DB00152  DOID_9970      true         1.0                Thiamine
# 80058   DB00150  DOID_9970      true         1.0            L-Tryptophan
# 74578   DB01623  DOID_9970      true         1.0             Thiothixene
# 76633   DB00120  DOID_9970      true         1.0         L-Phenylalanine
# 74852   DB01166  DOID_9970      true         1.0              Cilostazol
# 74989   DB01240  DOID_9970      true         1.0            Epoprostenol
# 75126   DB00820  DOID_9970      true         1.0               Tadalafil
# 75811   DB00093  DOID_9970      true         1.0             Felypressin
# 76222   DB00117  DOID_9970      true         1.0             L-Histidine
# 76359   DB00118  DOID_9970      true         1.0    S-Adenosylmethionine
# 76496   DB00119  DOID_9970      true         1.0            Pyruvic acid
# 76907   DB00123  DOID_9970      true         1.0                L-Lysine
# 79921   DB00149  DOID_9970      true         1.0               L-Leucine
# 77455   DB00129  DOID_9970      true         1.0             L-Ornithine
# 78140   DB00134  DOID_9970      true         1.0            L-Methionine
# 78414   DB00137  DOID_9970      true         1.0             Xanthophyll
# 78551   DB00138  DOID_9970      true         1.0               L-Cystine
# 79236   DB00144  DOID_9970      true         1.0      Phosphatidylserine
# 79373   DB00145  DOID_9970      true         1.0                 Glycine
# 79784   DB00148  DOID_9970      true         1.0                Creatine
# 210345  DB01593  DOID_9970      true         1.0                    Zinc
#
#                                           drug_categories disease_name  \
# 7859    Adrenergic beta-2 Receptor Agonists|Bronchodil...      obesity
# 162532                                       Sulfonamides      obesity
# 144448                                                NaN      obesity
# 144722  Antihypertensive Agents|Anti-Arrhythmia Agents...      obesity
# 144859                Anesthetics, Inhalation|Anesthetics      obesity
# 144996  Oxytocics|Abortifacient Agents, Nonsteroidal|A...      obesity
# 145133                                 Anesthetics, Local      obesity
# 145407           Antineoplastic Agents|Homeopathic Agents      obesity
# 146092                                                NaN      obesity
# 146229  Anti-Arrhythmia Agents|Voltage-Gated Sodium Ch...      obesity
# 146366  Narcotic Antagonists|Central Nervous System De...      obesity
# 146503                                                NaN      obesity
# 146777                            Anesthetics, Inhalation      obesity
# 146914  Serotonin Uptake Inhibitors|Anti-Obesity Agent...      obesity
# 147462  Leprostatic Agents|Antibiotics, Antitubercular...      obesity
# 148558                                                NaN      obesity
# 148695  5-alpha Reductase Inhibitors|Skin and Mucous M...      obesity
# 148969      Gastrointestinal Agents|Anti-Infective Agents      obesity
# 149517                       Analgesics, Opioid|Narcotics      obesity
# 144311                                  Antifungal Agents      obesity
# 144174                                 Parasympatholytics      obesity
# 144037                                        Penicillins      obesity
# 141571     Histamine H1 Antagonists|Histamine Antagonists      obesity
# 139105                                                NaN      obesity
# 139242                                                NaN      obesity
# 139790  Free Radical Scavengers|Solvents|Cryoprotectiv...      obesity
# 139927                                                NaN      obesity
# 140201                                                NaN      obesity
# 140475                                                NaN      obesity
# 141160  Antifungal Agents|14-alpha Demethylase Inhibitors      obesity
# ...                                                   ...          ...
# 82387      Dietary Supplements|Micronutrients|Supplements      obesity
# 80195   Dietary Supplements|Nutritional Support|Supple...      obesity
# 82524   Dietary Supplements|Micronutrients|Supplements...      obesity
# 82798   Dietary Supplements|Micronutrients|Supplements...      obesity
# 82935   Antineoplastic Agents|Antioxidants|Cyclooxygen...      obesity
# 83072                                   Diagnostic Agents      obesity
# 83209                                                 NaN      obesity
# 83620                    Antiviral Agents|Antimetabolites      obesity
# 83757                                   Antifungal Agents      obesity
# 80332                          Vitamin B Complex|Vitamins      obesity
# 80058   Antidepressive Agents, Second-Generation|Dieta...      obesity
# 74578   Antipsychotic Agents|Dopamine Antagonists|Thio...      obesity
# 76633   Dietary Supplements|Micronutrients|Amino Acids...      obesity
# 74852   Fibrinolytic Agents|Platelet Aggregation Inhib...      obesity
# 74989   Platelet Aggregation Inhibitors|Antihypertensi...      obesity
# 75126   Vasodilator Agents|Phosphodiesterase 5 Inhibitors      obesity
# 75811                 Vasoconstrictor Agents|Renal Agents      obesity
# 76222   Dietary Supplements|Micronutrients|Conditional...      obesity
# 76359      Dietary Supplements|Micronutrients|Supplements      obesity
# 76496      Dietary Supplements|Micronutrients|Supplements      obesity
# 76907   Dietary Supplements|Micronutrients|Amino Acids...      obesity
# 79921   Dietary Supplements|Micronutrients|Amino Acids...      obesity
# 77455   Dietary Supplements|Micronutrients|Supplements...      obesity
# 78140   Dietary Supplements|Micronutrients|Amino Acids...      obesity
# 78414      Dietary Supplements|Micronutrients|Supplements      obesity
# 78551   Dietary Supplements|Micronutrients|Supplements...      obesity
# 79236      Dietary Supplements|Micronutrients|Supplements      obesity
# 79373   Glycine Agents|Dietary Supplements|Micronutrie...      obesity
# 79784      Dietary Supplements|Micronutrients|Supplements      obesity
# 210345                                     Trace Elements      obesity
#
#        disease_pathophysiology
# 7859                 metabolic
# 162532               metabolic
# 144448               metabolic
# 144722               metabolic
# 144859               metabolic
# 144996               metabolic
# 145133               metabolic
# 145407               metabolic
# 146092               metabolic
# 146229               metabolic
# 146366               metabolic
# 146503               metabolic
# 146777               metabolic
# 146914               metabolic
# 147462               metabolic
# 148558               metabolic
# 148695               metabolic
# 148969               metabolic
# 149517               metabolic
# 144311               metabolic
# 144174               metabolic
# 144037               metabolic
# 141571               metabolic
# 139105               metabolic
# 139242               metabolic
# 139790               metabolic
# 139927               metabolic
# 140201               metabolic
# 140475               metabolic
# 141160               metabolic
# ...                        ...
# 82387                metabolic
# 80195                metabolic
# 82524                metabolic
# 82798                metabolic
# 82935                metabolic
# 83072                metabolic
# 83209                metabolic
# 83620                metabolic
# 83757                metabolic
# 80332                metabolic
# 80058                metabolic
# 74578                metabolic
# 76633                metabolic
# 74852                metabolic
# 74989                metabolic
# 75126                metabolic
# 75811                metabolic
# 76222                metabolic
# 76359                metabolic
# 76496                metabolic
# 76907                metabolic
# 79921                metabolic
# 77455                metabolic
# 78140                metabolic
# 78414                metabolic
# 78551                metabolic
# 79236                metabolic
# 79373                metabolic
# 79784                metabolic
# 210345               metabolic
#
# [642 rows x 8 columns]

# %% [markdown]
# ### Discussion
#
# All cases ~60% drugs are predicted as true with a probability of P = 1.0!!!

# %% [markdown]
# ### NGLY1 deficiency DOID:0060728

# %%
# predictions
print('True predictions: {} ({}%)'.format(len(predictions_df.query('disease == "DOID_0060728" & predicted == "true"')),round(len(predictions_df.query('disease == "DOID_0060728" & predicted == "true"'))*100/len(predictions_df.query('disease == "DOID_0060728"')))))
print()
true = predictions_df.query('disease == "DOID_0060728" & predicted == "true"')
print('Percentage of true predictions (P = 1): {}%'.format(round(
            100*len(true.query('prediction == 1'))/len(true)))
     )
print('Number of true predictions (P = 1): {}'.format(
            len(true.query('prediction == 1')))
     )
predictions_df.query('disease == "DOID_0060728" & predicted == "true" & prediction == 1.').sort_values(by= 'prediction', ascending= False)
# Out:
# True predictions: 158 (10%)
#
# Percentage of true predictions (P = 1): 34%
# Number of true predictions (P = 1): 53
#            drug       disease predicted  prediction                 drug_name  \
# 8630    DB00651  DOID_0060728      true         1.0                Dyphylline
# 139191  DB01088  DOID_0060728      true         1.0                  Iloprost
# 140561  DB01102  DOID_0060728      true         1.0                Arbutamine
# 146452  DB01183  DOID_0060728      true         1.0                  Naloxone
# 147548  DB01201  DOID_0060728      true         1.0               Rifapentine
# 149055  DB01220  DOID_0060728      true         1.0                 Rifaximin
# 153850  DB01329  DOID_0060728      true         1.0              Cefoperazone
# 154261  DB01333  DOID_0060728      true         1.0                 Cefradine
# 157275  DB01382  DOID_0060728      true         1.0              Glycodiazine
# 170564  DB04920  DOID_0060728      true         1.0               Clevidipine
# 173304  DB06155  DOID_0060728      true         1.0                Rimonabant
# 173578  DB06203  DOID_0060728      true         1.0                Alogliptin
# 173989  DB06209  DOID_0060728      true         1.0                 Prasugrel
# 174126  DB06210  DOID_0060728      true         1.0               Eltrombopag
# 179606  DB06716  DOID_0060728      true         1.0               Fospropofol
# 180291  DB06730  DOID_0060728      true         1.0                 Gestodene
# 180702  DB06766  DOID_0060728      true         1.0               Alcaftadine
# 181798  DB06804  DOID_0060728      true         1.0               Nonoxynol-9
# 183442  DB08804  DOID_0060728      true         1.0      Nandrolone decanoate
# 184401  DB08819  DOID_0060728      true         1.0                Tafluprost
# 184675  DB08822  DOID_0060728      true         1.0      Azilsartan medoxomil
# 186045  DB08874  DOID_0060728      true         1.0               Fidaxomicin
# 195361  DB04571  DOID_0060728      true         1.0                Trioxsalen
# 202622  DB06768  DOID_0060728      true         1.0          Ammonium lactate
# 209746  DB00885  DOID_0060728      true         1.0                Pemirolast
# 139328  DB01089  DOID_0060728      true         1.0               Deserpidine
# 135492  DB01031  DOID_0060728      true         1.0                Ethinamate
# 10137   DB00816  DOID_0060728      true         1.0             Orciprenaline
# 128094  DB00899  DOID_0060728      true         1.0              Remifentanil
# 40825   DB01045  DOID_0060728      true         1.0                Rifampicin
# 43702   DB00501  DOID_0060728      true         1.0                Cimetidine
# 46990   DB05812  DOID_0060728      true         1.0               Abiraterone
# 50004   DB00305  DOID_0060728      true         1.0                 Mitomycin
# 65622   DB00918  DOID_0060728      true         1.0               Almotriptan
# 76993   DB00123  DOID_0060728      true         1.0                  L-Lysine
# 80007   DB00149  DOID_0060728      true         1.0                 L-Leucine
# 80144   DB00150  DOID_0060728      true         1.0              L-Tryptophan
# 82884   DB00174  DOID_0060728      true         1.0              L-Asparagine
# 90830   DB00306  DOID_0060728      true         1.0                  Talbutal
# 90967   DB00308  DOID_0060728      true         1.0                 Ibutilide
# 91378   DB00319  DOID_0060728      true         1.0              Piperacillin
# 93844   DB00364  DOID_0060728      true         1.0                Sucralfate
# 96173   DB00395  DOID_0060728      true         1.0              Carisoprodol
# 98365   DB00430  DOID_0060728      true         1.0               Cefpiramide
# 100831  DB00473  DOID_0060728      true         1.0                Hexylcaine
# 102749  DB00512  DOID_0060728      true         1.0                Vancomycin
# 110010  DB00615  DOID_0060728      true         1.0                 Rifabutin
# 112202  DB00653  DOID_0060728      true         1.0         Magnesium Sulfate
# 114942  DB00720  DOID_0060728      true         1.0                Clodronate
# 118230  DB00761  DOID_0060728      true         1.0        Potassium Chloride
# 121929  DB00823  DOID_0060728      true         1.0                Ethynodiol
# 125765  DB00868  DOID_0060728      true         1.0               Benzonatate
# 210020  DB08913  DOID_0060728      true         1.0  Radium Ra 223 Dichloride
#
#                                           drug_categories disease_name  \
# 8630    Phosphodiesterase Inhibitors|Bronchodilator Ag...          NaN
# 139191                                                NaN          NaN
# 140561                                                NaN          NaN
# 146452  Narcotic Antagonists|Central Nervous System De...          NaN
# 147548  Leprostatic Agents|Antibiotics, Antitubercular...          NaN
# 149055      Gastrointestinal Agents|Anti-Infective Agents          NaN
# 153850               Anti-Bacterial Agents|Cephalosporins          NaN
# 154261               Anti-Bacterial Agents|Cephalosporins          NaN
# 157275                                                NaN          NaN
# 170564                                                NaN          NaN
# 173304                                                NaN          NaN
# 173578  Dipeptidyl-Peptidase IV Inhibitors|Antidiabeti...          NaN
# 173989                    Platelet Aggregation Inhibitors          NaN
# 174126                              Thrombopoietic Agents          NaN
# 179606                            Hypnotics and Sedatives          NaN
# 180291         Contraceptives, Oral, Synthetic|Progestins          NaN
# 180702  Anti-Inflammatory Agents|Histamine H1 Antagonists          NaN
# 181798                               Contraceptive Agents          NaN
# 183442                                    Anabolic Agents          NaN
# 184401              Prostaglandins, Synthetic|Ophthalmics          NaN
# 184675                   Angiotensin Receptor Antagonists          NaN
# 186045                                        Antibiotics          NaN
# 195361                            Photosensitizing Agents          NaN
# 202622                                      Antipruritics          NaN
# 209746                  Histamine Antagonists|Ophthalmics          NaN
# 139328                                                NaN          NaN
# 135492                                                NaN          NaN
# 10137   Sympathomimetics|Adrenergic beta-2 Receptor Ag...          NaN
# 128094  Hypnotics and Sedatives|Anesthetics, Intraveno...          NaN
# 40825   Enzyme Inhibitors|Antitubercular Agents|Nuclei...          NaN
# 43702                                           Adjuvants          NaN
# 46990                                                 NaN          NaN
# 50004   Nucleic Acid Synthesis Inhibitors|Antibiotics,...          NaN
# 65622   Serotonin Antagonists|Serotonin Receptor Agoni...          NaN
# 76993   Dietary Supplements|Micronutrients|Amino Acids...          NaN
# 80007   Dietary Supplements|Micronutrients|Amino Acids...          NaN
# 80144   Antidepressive Agents, Second-Generation|Dieta...          NaN
# 82884   Dietary Supplements|Micronutrients|Supplements...          NaN
# 90830                                                 NaN          NaN
# 90967                              Anti-Arrhythmia Agents          NaN
# 91378                   Anti-Bacterial Agents|Penicillins          NaN
# 93844                                                 NaN          NaN
# 96173   Muscle Relaxants, Central|Neuromuscular Agents...          NaN
# 98365                Anti-Bacterial Agents|Cephalosporins          NaN
# 100831                                 Anesthetics, Local          NaN
# 102749                              Anti-Bacterial Agents          NaN
# 110010  Anti-Bacterial Agents|Antibiotics, Antitubercular          NaN
# 112202  Anti-Arrhythmia Agents|Analgesics|Anticonvulsa...          NaN
# 114942  Bone Density Conservation Agents|Antihypocalce...          NaN
# 118230                                                NaN          NaN
# 121929                    Contraceptives, Oral, Synthetic          NaN
# 125765                                 Antitussive Agents          NaN
# 210020                                  Diagnostic Agents          NaN
#
#        disease_pathophysiology
# 8630                       NaN
# 139191                     NaN
# 140561                     NaN
# 146452                     NaN
# 147548                     NaN
# 149055                     NaN
# 153850                     NaN
# 154261                     NaN
# 157275                     NaN
# 170564                     NaN
# 173304                     NaN
# 173578                     NaN
# 173989                     NaN
# 174126                     NaN
# 179606                     NaN
# 180291                     NaN
# 180702                     NaN
# 181798                     NaN
# 183442                     NaN
# 184401                     NaN
# 184675                     NaN
# 186045                     NaN
# 195361                     NaN
# 202622                     NaN
# 209746                     NaN
# 139328                     NaN
# 135492                     NaN
# 10137                      NaN
# 128094                     NaN
# 40825                      NaN
# 43702                      NaN
# 46990                      NaN
# 50004                      NaN
# 65622                      NaN
# 76993                      NaN
# 80007                      NaN
# 80144                      NaN
# 82884                      NaN
# 90830                      NaN
# 90967                      NaN
# 91378                      NaN
# 93844                      NaN
# 96173                      NaN
# 98365                      NaN
# 100831                     NaN
# 102749                     NaN
# 110010                     NaN
# 112202                     NaN
# 114942                     NaN
# 118230                     NaN
# 121929                     NaN
# 125765                     NaN
# 210020                     NaN
